# %%
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px
import numpy as np

# %%
happiness2020 = pd.read_csv('happiness2020.csv')

# %%
pd.DataFrame.head(happiness2020)
# Out:
#    Unnamed: 0  Country name  Happiness score  Dystopia + residual  \
# 0           2   Switzerland           7.5599             2.350267
# 1           5   Netherlands           7.4489             2.352117
# 2           7   New Zealand           7.2996             2.128108
# 3          10        Canada           7.2321             2.195269
# 4          26  Saudi Arabia           6.4065             2.203119
#
#    Explained by: Log GDP per capita  Explained by: Social support  \
# 0                          1.390774                      1.472403
# 1                          1.338946                      1.463646
# 2                          1.242318                      1.487218
# 3                          1.301648                      1.435392
# 4                          1.334329                      1.309950
#
#    Explained by: Healthy life expectancy  \
# 0                               1.040533
# 1                               0.975675
# 2                               1.008138
# 3                               1.022502
# 4                               0.759818
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                    0.628954                  0.269056
# 1                                    0.613626                  0.336318
# 2                                    0.646790                  0.325726
# 3                                    0.644028                  0.281529
# 4                                    0.548477                  0.087441
#
#    Explained by: Perceptions of corruption
# 0                                 0.407946
# 1                                 0.368570
# 2                                 0.461268
# 3                                 0.351702
# 4                                 0.163322

# %% [markdown]
# ## Inflatie vs generosity
# Ik wil kijken naar het verschil in de inflatie van 2020 en 2022.
#
# - In 2020 was de inflatie aanzienelijk lager dan in 2022.
# - Is de overall happiness score of generosity in 2022 gedaald ten opzichte van 2020?
# - Kan dit verklaard worden door inflatie?

# %% [markdown]
# ### Happiness en Generosity in 2020 vs 2022
#
# - Landen op de X as
# - Balk voor 2020 en balk voor 2022 in een graph
# - Happiness score en generosity op de y as (aparte graph voor elk fenomeen)
#
# Vraag: is de inflatie wel in elk gekozen land hoger in 2022 dan in 2020
